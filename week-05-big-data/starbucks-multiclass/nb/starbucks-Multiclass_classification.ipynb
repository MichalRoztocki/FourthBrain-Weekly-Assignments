# %% [markdown]
# <p align = "center" draggable=”false” ><img src="https://user-images.githubusercontent.com/37101144/161836199-fdb0219d-0361-4988-bf26-48b0fad160a3.png"
#      width="200px"
#      height="auto"/>
# </p>

# %% [markdown]
# # **Bonus Challenge! - Taking it to the Next Level 📶**

# %% [markdown]
# ## :coffee: Starbucks Promotional Offers
#
# Starbucks Corporation is the leading roaster, retailer, and marketer of specialty coffee in the world.  Starbucks' mobile app routinely pushes offers to customers in hopes that it will entice the customer to visit to one of their many local coffeehouses.   The offers may be promotional like a **discount** on a seasonal beverage or pastry or **BOGO (Buy One Get One free)** or an **informational** whichs is an advertisement for a product.  Some users may receive offers more frequently than others.
#
# In this challenge:
#
# 1. We want to predict the responsiveness of a customer to an offer - i.e. how likely they are to make a purchase after receiving an offer.
#
# 2. We will use Spark and will introduce the Pandas on Spark API - this will help out with your Exploratory Data Analysis (EDA) and Feature Engineering.
#
# 3. You will be responsible for the majority of coding in the section, but you will be not left alone!  If you get stuck, look at the dropdown hints (🤔 **Hints**).  The hints will start off vague and get increasingly more specific to help guide you through the challenge.
#
# 5. You will use **multiclass classification** techniques in Spark to classify customer responsiveness to promotional offer campaigns.

# %% [markdown]
# # Multiclass (Multi-label) Classification
#
# [Multiclass classification](https://en.wikipedia.org/wiki/Multi-label_classification) is an extension of binary classification with more than two labels where each label is an binary classification model.  The model that produces the highest probability score for the label is the label becomes the label prediction for the input.

# %% [markdown]
# # Spark Environment
# ### Make sure to run this notebook in your Spark environment!

# %% [markdown]
# # **Get the Data**
#
# There are three datasets in this challenge.  **Portfolio** contains the different offer campaigns, **Profile** contains the customer profile, and **Transcript** contains the user interactions with the offer campaigns.  Have a look 👀 for yourself!

# %% [markdown]
# Love 🐼 Pandas?  Love Spark? Let's combine them!  Born out of a Databricks project called 🐨 Koalas, [Pandas on Spark](https://spark.apache.org/docs/latest/api/python/user_guide/pandas_on_spark/index.html), allows us to utilize the Pandas API distributed on Spark!  Check out this [article](https://towardsdatascience.com/run-pandas-as-fast-as-spark-f5eefe780c45) for a nice quickstart as well as the official [API Documentation](https://spark.apache.org/docs/3.3.0/api/python/reference/index.html)!

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pyspark.pandas as ps

psdf_portfolio = ps.read_csv("/FileStore/tables/starbucks_opt_assignment/portfolio.csv")
psdf_profile = ps.read_csv("/FileStore/tables/starbucks_opt_assignment/profile.csv")
psdf_transcript = ps.read_csv("/FileStore/tables/starbucks_opt_assignment/transcript.csv")

# %%
psdf_portfolio.head()
psdf_profile.head()
psdf_transcript.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>reward</th>
#       <th>channels</th>
#       <th>difficulty</th>
#       <th>duration</th>
#       <th>offer_type</th>
#       <th>id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>10</td>
#       <td>['email', 'mobile', 'social']</td>
#       <td>10</td>
#       <td>7</td>
#       <td>bogo</td>
#       <td>ae264e3637204a6fb9bb56bc8210ddfd</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>10</td>
#       <td>['web', 'email', 'mobile', 'social']</td>
#       <td>10</td>
#       <td>5</td>
#       <td>bogo</td>
#       <td>4d5c57ea9a6940dd891ad53e9dbe8da0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>0</td>
#       <td>['web', 'email', 'mobile']</td>
#       <td>0</td>
#       <td>4</td>
#       <td>informational</td>
#       <td>3f207df678b143eea3cee63160fa8bed</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>5</td>
#       <td>['web', 'email', 'mobile']</td>
#       <td>5</td>
#       <td>7</td>
#       <td>bogo</td>
#       <td>9b98b8c7a33c4b65b9aebfe6a799e6d9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>5</td>
#       <td>['web', 'email']</td>
#       <td>20</td>
#       <td>10</td>
#       <td>discount</td>
#       <td>0b1e1539f2cc45b7b9fa7c272da2e1d7</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>gender</th>
#       <th>age</th>
#       <th>id</th>
#       <th>became_member_on</th>
#       <th>income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>None</td>
#       <td>118</td>
#       <td>68be06ca386d4c31939f3a4f0e3dd783</td>
#       <td>20170212</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>F</td>
#       <td>55</td>
#       <td>0610b486422d4921ae7d2bf64640c50b</td>
#       <td>20170715</td>
#       <td>112000.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>None</td>
#       <td>118</td>
#       <td>38fe809add3b4fcf9315a9694bb96ff5</td>
#       <td>20180712</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>F</td>
#       <td>75</td>
#       <td>78afa995795e4d85b5d9ceeca43f5fef</td>
#       <td>20170509</td>
#       <td>100000.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>None</td>
#       <td>118</td>
#       <td>a03223e636434f42ac4c3df47e8bac43</td>
#       <td>20170804</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>person</th>
#       <th>event</th>
#       <th>value</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>78afa995795e4d85b5d9ceeca43f5fef</td>
#       <td>offer received</td>
#       <td>{'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>a03223e636434f42ac4c3df47e8bac43</td>
#       <td>offer received</td>
#       <td>{'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>e2127556f4f64592b11af22de27a7932</td>
#       <td>offer received</td>
#       <td>{'offer id': '2906b810c7d4411798c6938adc9daaa5'}</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>8ec6ce2a7e7949b1bf142def7d0e0586</td>
#       <td>offer received</td>
#       <td>{'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>68617ca6246f4fbc85e91a2a49552598</td>
#       <td>offer received</td>
#       <td>{'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # **Explore the Data - EDA**
#
# It's your turn to practice EDA!  Perform either manual EDA or use automated EDA tools like SweetViz!  Get to know the data, what do you notice, what stands out?

# %% [markdown]
# ## **🤔 Hints**
# <details>
# <summary>Hint 1</summary>
# Take a look at each dataset independently.  What do you notice?  Are there any missing values? Are there values that don't make sense? What are the unique events?
# <br></br>
# </details>
#
# <details>
# <summary>Hint 2</summary>
# Is the dataset balanced?
# <br></br>
# </details>
#
# <details>
# <summary>Hint 3</summary>
# Notice that the challenge is to predict customer responsiveness. How can responsiveness be represented in the data?
# </details>

# %% [markdown]
# ## Exploring Portfolio Dataframe

# %%
psdf_portfolio.shape
print("\n")
psdf_portfolio.dtypes # YOUR CODE GOES HERE!
print("\n")
psdf_portfolio.isnull().sum()
# Out:
# Out[70]: (10, 7)
#
# Out[70]: _c0            int32
# reward         int32
# channels      object
# difficulty     int32
# duration       int32
# offer_type    object
# id            object
# dtype: object
#
# Out[70]: _c0           0
# reward        0
# channels      0
# difficulty    0
# duration      0
# offer_type    0
# id            0
# dtype: int64

# %% [markdown]
# No missing values in the portfolio dataset and all data types as expected. Only 10 campaigns so we can view them all at once.

# %%
psdf_portfolio.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>reward</th>
#       <th>channels</th>
#       <th>difficulty</th>
#       <th>duration</th>
#       <th>offer_type</th>
#       <th>id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>10</td>
#       <td>['email', 'mobile', 'social']</td>
#       <td>10</td>
#       <td>7</td>
#       <td>bogo</td>
#       <td>ae264e3637204a6fb9bb56bc8210ddfd</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>10</td>
#       <td>['web', 'email', 'mobile', 'social']</td>
#       <td>10</td>
#       <td>5</td>
#       <td>bogo</td>
#       <td>4d5c57ea9a6940dd891ad53e9dbe8da0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>0</td>
#       <td>['web', 'email', 'mobile']</td>
#       <td>0</td>
#       <td>4</td>
#       <td>informational</td>
#       <td>3f207df678b143eea3cee63160fa8bed</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>5</td>
#       <td>['web', 'email', 'mobile']</td>
#       <td>5</td>
#       <td>7</td>
#       <td>bogo</td>
#       <td>9b98b8c7a33c4b65b9aebfe6a799e6d9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>5</td>
#       <td>['web', 'email']</td>
#       <td>20</td>
#       <td>10</td>
#       <td>discount</td>
#       <td>0b1e1539f2cc45b7b9fa7c272da2e1d7</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>3</td>
#       <td>['web', 'email', 'mobile', 'social']</td>
#       <td>7</td>
#       <td>7</td>
#       <td>discount</td>
#       <td>2298d6c36e964ae4a3e7e9706d1fb8c2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>2</td>
#       <td>['web', 'email', 'mobile', 'social']</td>
#       <td>10</td>
#       <td>10</td>
#       <td>discount</td>
#       <td>fafdcd668e3743c1bb461111dcafc2a4</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>0</td>
#       <td>['email', 'mobile', 'social']</td>
#       <td>0</td>
#       <td>3</td>
#       <td>informational</td>
#       <td>5a8bc65990b245e5a138643cd4eb9837</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>5</td>
#       <td>['web', 'email', 'mobile', 'social']</td>
#       <td>5</td>
#       <td>5</td>
#       <td>bogo</td>
#       <td>f19421c1d4aa40978ebb69ca19b0e20d</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>2</td>
#       <td>['web', 'email', 'mobile']</td>
#       <td>10</td>
#       <td>7</td>
#       <td>discount</td>
#       <td>2906b810c7d4411798c6938adc9daaa5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print(psdf_portfolio.offer_type.value_counts())
# Out:
# discount         4
# bogo             4
# informational    2
# Name: offer_type, dtype: int64

# %% [markdown]
# There were 4 discount campaigns, 4 BOGO campaigns, and 2 informational campaigns.

# %%
psdf_portfolio.sort_values("offer_type")
psdf_portfolio.groupby("offer_type").mean()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>reward</th>
#       <th>channels</th>
#       <th>difficulty</th>
#       <th>duration</th>
#       <th>offer_type</th>
#       <th>id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>10</td>
#       <td>['email', 'mobile', 'social']</td>
#       <td>10</td>
#       <td>7</td>
#       <td>bogo</td>
#       <td>ae264e3637204a6fb9bb56bc8210ddfd</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>10</td>
#       <td>['web', 'email', 'mobile', 'social']</td>
#       <td>10</td>
#       <td>5</td>
#       <td>bogo</td>
#       <td>4d5c57ea9a6940dd891ad53e9dbe8da0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>5</td>
#       <td>['web', 'email', 'mobile']</td>
#       <td>5</td>
#       <td>7</td>
#       <td>bogo</td>
#       <td>9b98b8c7a33c4b65b9aebfe6a799e6d9</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>5</td>
#       <td>['web', 'email', 'mobile', 'social']</td>
#       <td>5</td>
#       <td>5</td>
#       <td>bogo</td>
#       <td>f19421c1d4aa40978ebb69ca19b0e20d</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>5</td>
#       <td>['web', 'email']</td>
#       <td>20</td>
#       <td>10</td>
#       <td>discount</td>
#       <td>0b1e1539f2cc45b7b9fa7c272da2e1d7</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>3</td>
#       <td>['web', 'email', 'mobile', 'social']</td>
#       <td>7</td>
#       <td>7</td>
#       <td>discount</td>
#       <td>2298d6c36e964ae4a3e7e9706d1fb8c2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>2</td>
#       <td>['web', 'email', 'mobile', 'social']</td>
#       <td>10</td>
#       <td>10</td>
#       <td>discount</td>
#       <td>fafdcd668e3743c1bb461111dcafc2a4</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>2</td>
#       <td>['web', 'email', 'mobile']</td>
#       <td>10</td>
#       <td>7</td>
#       <td>discount</td>
#       <td>2906b810c7d4411798c6938adc9daaa5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>0</td>
#       <td>['web', 'email', 'mobile']</td>
#       <td>0</td>
#       <td>4</td>
#       <td>informational</td>
#       <td>3f207df678b143eea3cee63160fa8bed</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>0</td>
#       <td>['email', 'mobile', 'social']</td>
#       <td>0</td>
#       <td>3</td>
#       <td>informational</td>
#       <td>5a8bc65990b245e5a138643cd4eb9837</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>reward</th>
#       <th>difficulty</th>
#       <th>duration</th>
#     </tr>
#     <tr>
#       <th>offer_type</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>discount</th>
#       <td>6.0</td>
#       <td>3.0</td>
#       <td>11.75</td>
#       <td>8.5</td>
#     </tr>
#     <tr>
#       <th>informational</th>
#       <td>4.5</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>3.5</td>
#     </tr>
#     <tr>
#       <th>bogo</th>
#       <td>3.0</td>
#       <td>7.5</td>
#       <td>7.50</td>
#       <td>6.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# On average, the difficulty and duration of discount campaigns were higher than with BOBO campaigns. The average reward for BOBO campaigns however was over twice as large.

# %%
psdf_portfolio.dtypes 
print("\n")
psdf_portfolio.isnull().sum()
# Out:
# Out[74]: _c0            int32
# reward         int32
# channels      object
# difficulty     int32
# duration       int32
# offer_type    object
# id            object
# dtype: object
#
# Out[74]: _c0           0
# reward        0
# channels      0
# difficulty    0
# duration      0
# offer_type    0
# id            0
# dtype: int64

# %% [markdown]
# ## Exploring Profile Dataframe

# %%
psdf_profile.shape
print("\n")
psdf_profile.dtypes
print("\n")
psdf_profile.isnull().sum()
# Out:
# Out[75]: (17000, 6)
#
# Out[75]: _c0                   int32
# gender               object
# age                   int32
# id                   object
# became_member_on      int32
# income              float64
# dtype: object
#
# Out[75]: _c0                    0
# gender              2175
# age                    0
# id                     0
# became_member_on       0
# income              2175
# dtype: int64

# %% [markdown]
# It's worth noting here that the number of missing values in gender and income are exactly the same, which is a bit suspect. Next, we'll check if these missing values coincide; when gender is missing, is income as well? If so, this might just mean that those particular customers filled in the minimum amount of data required about themselves.

# %%
(psdf_profile.gender.isnull() == psdf_profile.income.isnull()).sum()
# Out:
# Out[172]: 17000

# %% [markdown]
# As we can see from the above cell, whenever gender is missing, income is missing as well, and vice-versa.

# %%
print(psdf_profile.gender.unique())
print(psdf_profile.gender.value_counts())
# Out:
# 0       F
# 1    None
# 2       M
# 3       O
# Name: gender, dtype: object
# M    8484
# F    6129
# O     212
# Name: gender, dtype: int64

# %% [markdown]
# ### Investigating Age feature

# %%
import seaborn as sns

sns.histplot(data=psdf_profile.to_pandas(), x="age", bins=25)
# Out:
# Out[77]: <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# This distribution looks like a normal distribution except for the large amount of rows with age>100. Let's investigate these rows.

# %%
print(psdf_profile[[psdf_profile.age>110]].sum())
print(psdf_profile[psdf_profile.age>110].head())
print(psdf_profile[psdf_profile.age>110].age.unique())
print(f"The percentage of 118-year olds is {round(100*(psdf_profile[[psdf_profile.age>110]].sum()/psdf_profile.shape[0]).to_numpy()[0], 2)}%.")
# Out:
# age    2175
# dtype: int64
#    _c0 gender  age                                id  became_member_on  income
# 0    0   None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212     NaN
# 2    2   None  118  38fe809add3b4fcf9315a9694bb96ff5          20180712     NaN
# 4    4   None  118  a03223e636434f42ac4c3df47e8bac43          20170804     NaN
# 6    6   None  118  8ec6ce2a7e7949b1bf142def7d0e0586          20170925     NaN
# 7    7   None  118  68617ca6246f4fbc85e91a2a49552598          20171002     NaN
# 0    118
# Name: age, dtype: int32
# The percentage of 118-year olds is 12.79%.

# %% [markdown]
# Since the population of 118 year olds at any time is very low, see [List of the Oldest People in the World](https://en.wikipedia.org/wiki/List_of_the_verified_oldest_people), we can safely assume that these were throwaway or silly responses from the customers in response to being asked about their age, and so we can replace all these values the mean of the other values (calculated by not taking into account "118-year olds"), by sampling from the normal distribution of the rest of the data, or by filling with 0's.

# %% [markdown]
# #### Age Feature Experiments

# %%
# Experiment 1: Filling misleading age values with mean of age column.
age_mean = psdf_profile[psdf_profile.age<118].age.mean()
print(age_mean)
age_mean_df = psdf_profile.replace({'age': 118}, age_mean)
age_mean_df.head()
# Out:
# 54.39352445193929
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>gender</th>
#       <th>age</th>
#       <th>id</th>
#       <th>became_member_on</th>
#       <th>income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>None</td>
#       <td>54.393524</td>
#       <td>68be06ca386d4c31939f3a4f0e3dd783</td>
#       <td>20170212</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>F</td>
#       <td>55.000000</td>
#       <td>0610b486422d4921ae7d2bf64640c50b</td>
#       <td>20170715</td>
#       <td>112000.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>None</td>
#       <td>54.393524</td>
#       <td>38fe809add3b4fcf9315a9694bb96ff5</td>
#       <td>20180712</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>F</td>
#       <td>75.000000</td>
#       <td>78afa995795e4d85b5d9ceeca43f5fef</td>
#       <td>20170509</td>
#       <td>100000.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>None</td>
#       <td>54.393524</td>
#       <td>a03223e636434f42ac4c3df47e8bac43</td>
#       <td>20170804</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sns.histplot(data=age_mean_df.to_pandas(), x="age", bins=25)
# Out:
# Out[178]: <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
age_mean_df.age.mean(), age_mean
age_mean_df.age.std(), psdf_profile[psdf_profile.age<118].age.std()
# Out:
# Out[179]: (54.39352445194238, 54.39352445193929)Out[179]: (16.233544983314662, 17.383705365855015)

# %% [markdown]
# This looks like an improvement (we retained the mean and standard deviation), but now we've changed the distribution of our age feature (of the non-118 values) and it's no longer a normal distribution. Let's instead try to replace the 118-year-olds with 0's.

# %%
# Experiment 2: Filling misleading age values with 0's
age_zero_df = psdf_profile.replace({'age': 118}, 0)
age_zero_df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>gender</th>
#       <th>age</th>
#       <th>id</th>
#       <th>became_member_on</th>
#       <th>income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#       <td>68be06ca386d4c31939f3a4f0e3dd783</td>
#       <td>20170212</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>F</td>
#       <td>55</td>
#       <td>0610b486422d4921ae7d2bf64640c50b</td>
#       <td>20170715</td>
#       <td>112000.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>None</td>
#       <td>0</td>
#       <td>38fe809add3b4fcf9315a9694bb96ff5</td>
#       <td>20180712</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>F</td>
#       <td>75</td>
#       <td>78afa995795e4d85b5d9ceeca43f5fef</td>
#       <td>20170509</td>
#       <td>100000.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>None</td>
#       <td>0</td>
#       <td>a03223e636434f42ac4c3df47e8bac43</td>
#       <td>20170804</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sns.histplot(data=age_zero_df.to_pandas(), x="age", bins=25)
# Out:
# Out[182]: <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# Of course, someone of an age of 0 being a starbucks customer doesn't make sense, but we'll keep both this dataframe and the the mean-filled dataframe and test which is better during validation.

# %% [markdown]
# ### Taking care of missing values in profile dataframe

# %% [markdown]
# #### Addressing the missing values in gender

# %%
psdf_profile.gender.plot(kind="bar")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4b39b6ce-8854-449c-9d58-4c6855f0165e" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b39b6ce-8854-449c-9d58-4c6855f0165e")) {                    Plotly.newPlot(                        "4b39b6ce-8854-449c-9d58-4c6855f0165e",                        [{"alignmentgroup":"True","hovertemplate":"variable=gender<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"gender","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"gender","offsetgroup":"gender","orientation":"v","showlegend":true,"textposition":"auto","x":[null,"F",null,"F",null,"M",null,null,"M",null,null,null,"M","F","M","F","M",null,"M","F","F","M","F",null,"M","F",null,"F","F","M","M","O","M","F","M","F",null,"M","F",null,"M","F","M","M",null,null,"F","F","M","F","F","F","F","F",null,"M",null,null,"F","M","M","M","M","M","F","M","M","M","M","M","M","F","F","F
F","F","O","M","M","M","M","F","M","M","F","F","F","F","F","M","M","F","M","M","F","F","M","N","M","M","M","F","M","F","N","M","M","F","F","F","M","M","M","N","F","M","N","F","F","M","F","M","M","M","F","F","N","F","M","M","M","M","N","F","F","F","F","N","M","N","F","N","M","N","M","F","F","M","M","M","M","N","M","F","N","N","M","M","M","F","F","N","F","M","M","F","F","F","M","N","M","M","M","N","M","F","M","N","N","F","M","M","N","N","F","F","O","F","M","M","F","M","M","F","F","M","N","F","F","M","M","F","F","M","F","M","M","F","M","F","F","F","M","M","M","M","F","M","N","F","M","N","N","F","F","M","M","F","M","N","M","M","M","F","M","F","M","M","M","F","M","F","M","F","M","F","M","M","M","M","M","F","M","F","F","M","M","F","M","F","M","N","F","M","M","F","F","F","F","M","N","M","N","N","F","N","M","M","M","F","F","M","M","M","F","M","M","M","M","F","M","F","N","N","N","M","N","M","M","F","M","M","M","M","F","M","F","F","M","M","M","M","F","M","F","F","O","M","M","M","N","M","F","F","M","N","M","M","F","F","M","M","M","M","M","F","F","N","M","F","N","N","M","M","M","F","M","N","F","F","F","N","F","F","F","F","N","M","M","F","M","N","F","N","N","F","M","F","N","F","M","F","M","M","F","M","M","M","M","O","M","F","F","M","M","F","M","F","F","M","M","M","M","F","N","F","F","M","M","F","F","M","M","F","M","M","F","F","N","M","F","N","N","M","F","F","F","N","M","M","M","F","N","F","M","N","N","M","M","F","N","F","F","F","M","M","N","F","F","F","M","M","N","M","F","F","F","F","F","F","F","F","M","M","M","M","F","F","N","M","M","N","F","M","F","M","F","M","M","M","M","F","M","F","M","M","F","M","M","F","M","F","F","M","M","F","M","F","N","F","M","M","M","M","F","F","M","M","F","F","M","M","M","F","M","M","F","M","M","N","F","M","M","M","M","F","M","M","F","M","M","M","M","F","N","F","M","M","M","F","F","M","N","F","M","N","M","M","N","M","M","F","M","M","M","M","M","M","F","N","M","M","M","M","F","M","F","F","M","M","F","F","F","N","N","F","M","N","F","M","M","F","F","M","F","N","F","M","M","M","M","F","M","N","F","N","N","F","N","M","N","F","M","F","N","M","F" ...

# %% [markdown]
# This looks like it might potentially be more promising than using the most frequent value, as it retains the distribution of the other categorical values and also encodes that the value was missing in the new dataframe.

# %% [markdown]
# #### Addressing the missing values in income

# %%
sns.histplot(data=psdf_profile.to_pandas(), x="income")
# Out:
# Out[203]: <AxesSubplot:xlabel='income', ylabel='Count'>

# %%
psdf_profile.income.isnull().sum()
# Out:
# Out[204]: 2175

# %% [markdown]
# The income feature isn't in a normal distribution, but there's nothing particularly strange about it as in the case with the age feature. We will once again try two different methods here: filling the missing values with the mean and 0.

# %%
# Experiment 1: Replacing missing income values with mean. Keep in mind that we're doing this to all 4 of the dataframes we created in the previous step.
# Note: For brevity in naming, a will represent age, g the gender, and i the income.
income_mean = psdf_profile.income.mean()

a_0_g_m_i_m_df = age_0_gen_m_df.fillna(income_mean)
a_0_g_n_i_m_df = age_0_gen_n_df.fillna(income_mean)

a_m_g_m_i_m_df = age_mean_gen_m_df.fillna(income_mean)
a_m_g_n_i_m_df = age_mean_gen_n_df.fillna(income_mean)

# %%
sns.histplot(data=a_m_g_m_i_m_df.to_pandas(), x="income")
# Out:
# Out[207]: <AxesSubplot:xlabel='income', ylabel='Count'>

# %% [markdown]
# Filling the income data with the mean might not be the best idea due to how much it changes the distribution of the data. Let's see if filling with 0's is any better.

# %%
# Experiment 2: Replacing missing income values with 0. Keep in mind that we're doing this to all 4 of the dataframes we created in the previous step.
# Note: For brevity in naming, a will represent age, g the gender, and i the income.

a_0_g_m_i_0_df = age_0_gen_m_df.fillna(0)
a_0_g_n_i_0_df = age_0_gen_n_df.fillna(0)

a_m_g_m_i_0_df = age_mean_gen_m_df.fillna(0)
a_m_g_n_i_0_df = age_mean_gen_n_df.fillna(0)

# %%
sns.histplot(data=a_m_g_m_i_0_df.to_pandas(), x="income")
# Out:
# Out[211]: <AxesSubplot:xlabel='income', ylabel='Count'>

# %% [markdown]
# This doesn't look too great either, but at least the non-0 income data has the same distribution as before. We now have 8 dataframes we can use to test out which methods of handling missing values work best with this dataset and problem domain.

# %% [markdown]
# ## Exploring Transcript Dataframe

# %%
print(psdf_transcript.shape)
psdf_transcript.isnull().sum()
# Out:
# (306534, 5)
# Out[212]: _c0       0
# person    0
# event     0
# value     0
# time      0
# dtype: int64

# %%
psdf_transcript.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>person</th>
#       <th>event</th>
#       <th>value</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>78afa995795e4d85b5d9ceeca43f5fef</td>
#       <td>offer received</td>
#       <td>{'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>a03223e636434f42ac4c3df47e8bac43</td>
#       <td>offer received</td>
#       <td>{'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>e2127556f4f64592b11af22de27a7932</td>
#       <td>offer received</td>
#       <td>{'offer id': '2906b810c7d4411798c6938adc9daaa5'}</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>8ec6ce2a7e7949b1bf142def7d0e0586</td>
#       <td>offer received</td>
#       <td>{'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>68617ca6246f4fbc85e91a2a49552598</td>
#       <td>offer received</td>
#       <td>{'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Clearly, the transcript dataset bring together both the customers from the profile dataset and the campaigns from the portfolio dataset. We can check this below, to make sure there are no id values in the person column other than the ones from the profile id column, as well as no offer id values other than the ones from the id column in the portfolio dataset.

# %%
print(psdf_transcript.person.nunique())
print(psdf_profile.id.nunique())
# Out:
# 17000
# 17000

# %%
sorted(psdf_transcript.person.unique().tolist()) == sorted(psdf_profile.id.unique().tolist())
# Out:
# Out[225]: True

# %% [markdown]
# From the above cell we know that our profile dataset contains all the customers that show up in the transcript dataset.

# %%
psdf_transcript.value.unique()[:10]
# Out:
# Out[230]: 0    {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...
# 1                                     {'amount': 1.78}
# 2                                     {'amount': 0.63}
# 3                                    {'amount': 28.41}
# 4                                    {'amount': 16.37}
# 5                                     {'amount': 4.17}
# 6                                    {'amount': 19.32}
# 7                                      {'amount': 6.1}
# 8                                    {'amount': 17.19}
# 9                                   {'amount': 103.28}
# Name: value, dtype: object

# %% [markdown]
# It looks like the value column either describes the campaign used or the size of the discount offered.

# %%
# psdf_transcript.value.unique().str.startswith("{'offer_id':")
psdf_transcript[psdf_transcript.value.str.startswith("{\'offer id\':")].shape
# Out:
# Out[238]: (134002, 5)

# %%
temp_df = psdf_transcript[psdf_transcript.value.str.startswith("{\'offer id\':")]
campaign_ids = temp_df.value.unique()#.str.lstrip("{\'offer id\': \'").str.rstrip("\'}")
print(campaign_ids)
# Out:
# 0    {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}
# 1    {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 2    {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 3    {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 4    {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}
# 5    {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}
# 6    {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 7    {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 8    {'offer id': '3f207df678b143eea3cee63160fa8bed'}
# 9    {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
# Name: value, dtype: object

# %%
sorted(campaign_ids.tolist()) == sorted(psdf_portfolio.id.unique().tolist())
# Out:
# Out[245]: False

# %%
print(sorted(psdf_portfolio.id.unique().tolist()))
print(sorted(campaign_ids.tolist()))
# Out:
# ['0b1e1539f2cc45b7b9fa7c272da2e1d7', '2298d6c36e964ae4a3e7e9706d1fb8c2', '2906b810c7d4411798c6938adc9daaa5', '3f207df678b143eea3cee63160fa8bed', '4d5c57ea9a6940dd891ad53e9dbe8da0', '5a8bc65990b245e5a138643cd4eb9837', '9b98b8c7a33c4b65b9aebfe6a799e6d9', 'ae264e3637204a6fb9bb56bc8210ddfd', 'f19421c1d4aa40978ebb69ca19b0e20d', 'fafdcd668e3743c1bb461111dcafc2a4']
# ['0b1e1539f2cc45b7b9fa7c272da2e1d7', '19421c1d4aa40978ebb69ca19b0e20d', '2298d6c36e964ae4a3e7e9706d1fb8c2', '2906b810c7d4411798c6938adc9daaa5', '3f207df678b143eea3cee63160fa8bed', '4d5c57ea9a6940dd891ad53e9dbe8da0', '5a8bc65990b245e5a138643cd4eb9837', '9b98b8c7a33c4b65b9aebfe6a799e6d9', 'ae264e3637204a6fb9bb56bc8210ddfd', 'afdcd668e3743c1bb461111dcafc2a4']

# %% [markdown]
# # **Setup the ETL Pipeline + Feature Engineering (The Art 🎨 🖌 of ML**)
#
# Bring the datasets together, perform feature engineering, rename columns, and drop columns that you don't need for predictions.
#
# **Required**: Create a feature for customer responsiveness using the event column in the transcript table.
#
#   *   Create **five** labels (one for each event + unresponsive) for customer responsiveness using a 5-point Likert scale:
#
#     1. Unresponsive,
#     2. Slightly Responsive,
#     3. Somewhat Responsive
#     4. Moderately Responsive,
#     5. Very Responsive.

# %% [markdown]
# ## **🤔 Hints**
# <details>
# <summary>Hint 1</summary>
# Take a look at the AGE, GENDER, and INCOME variables.  Do you notice anything unusual?  Do the values make sense?  How will you handle this?
# <br></br>
# </details>
#
# <details>
# <summary>Hint 2</summary>
# Are there any other features that you could create features for?
# <br></br>
# </details>
#
# <details>
# <summary>Hint 3</summary>
# As you bring the datasets together, what do you notice about the relationship between the customer and transcript tables?  Is it a one-to-one or a one-to-many relationship?
# <br></br>
# </details>
#
# <details>
# <summary>Hint 4</summary>
# Since the data has a one-to-many relationship between the customer and transcript tables. You will need flatten your dataset (i.e. in one row per customer).
# </details>
#
# <details>
# <summary>Hint 5</summary>
# Create binary features (dummy variables) for the channels, offer_type, and event variables.  Use the event dummy variables to create your customer responsiveness labels.
# <br></br>
# </details>

# %% [markdown]
# ### Here's a freebie! Let's create a row-level function to parse out the offer id value. This probably won't be the last time that you'll need it! 😉

# %%
import pandas as pd

# Row-level function to clean offer id in transcript table.
def get_offer_id(offer_id):
  offer_id = offer_id.split()[2]
  return offer_id[1:len(offer_id)-2]

psdf_transcript["offer_id"] = psdf_transcript["value"].apply(get_offer_id)

# Drop original value column
psdf_transcript = psdf_transcript.drop("value")

psdf_transcript.head()

# %%
# YOUR CODE GOES HERE!

# %% [markdown]
# # **Modeling**

# %% [markdown]
# ## Prepare your dataset for ML!

# %%
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler

# YOUR CODE GOES HERE!

# %% [markdown]
# ## Train-Test-Split

# %%
# YOUR CODE GOES HERE!

# %% [markdown]
# There are a couple different ways to setup a multiclass classifier as an extension of Logistic Regression in PySpark:
#
# 1.   Multinomial Logistic Regression (softmax)
# 2.   One vs Rest (OVR) / One vs All (OVA)

# %% [markdown]
# ### Multinomial Logistic Regression (softmax)
#
# Logistic Regression can be adapted to a multiclass task by using the setting the `family = "multinomial"`.

# %%
from pyspark.ml.classification import LogisticRegression

# Instantiate the classifier

# Fit the model 
# YOUR CODE GOES HERE!

# Make Predictions
# YOUR CODE GOES HERE!

# Evaluate the model
# YOUR CODE GOES HERE!

# %% [markdown]
# ### One vs Rest (OVR) / One vs All (OVA)

# %%
from pyspark.ml.classification import LogisticRegression, OneVsRest
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# instantiate the base Logistic Regression classifier.

# instantiate the One Vs Rest Classifier.
ovr = OneVsRest(classifier=lr)

# Fit the model 
# YOUR CODE GOES HERE!

# Make Predictions
# YOUR CODE GOES HERE!

# Evaluate the model
# YOUR CODE GOES HERE!

# %% [markdown]
# ## Setup Your Modeling Pipeline with Hyper Parameter Tuning

# %%
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

# YOUR CODE GOES HERE!

# %% [markdown]
# Additionally, you can solve Multiclass Classification problems using:
#
# 1.   Random Forest
# 2.   Decision Trees
# 3.   Naïve Bayes
#
# You can also extend the idea of multiclass classification to [multi-label multiclassification](https://en.wikipedia.org/wiki/Multi-label_classification).
#
# But that's another lesson...

# %% [markdown]
# ## Review Questions
#
# 1.  What are two other applications you could use multiclass classification for?
# 2.  What do you think the drawbacks to multiclass classifications are?
